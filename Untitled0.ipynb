# %% [markdown]
# <a href="https://colab.research.google.com/github/fgoldenboy19/Mineria-de-Datos/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejercicio 1
hermanos=2; #int Alliaon
print("yo tengo",hermanos,"hermanos.")

estatura = 1.85 #float
print("mi estatura es de", estatura,"m.")


EsMayor = True #boolean
print("¿La persona es mayor de edad?",EsMayor)

domicilio = "Av. Ing. Militares y Av. Mexico Tacuba" #string
print("La UTC Toreo se encuentra en",domicilio)


#EJERCICIO 2
resultado = ((4 + 5) / (6 * 4)) ** 2

print("El resultado es:", resultado)

#EJERCICIO 3
dividendo = int(input("Ingresa el dividendo: "))
divisor = int(input("Ingresa el divisor:"))
cociente = dividendo // divisor
residuo = dividendo % divisor
print(f"{dividendo} entre {divisor} da un cociente {cociente} y un residuo {residuo}")

#EJERCICIO 4
edad = 61
if edad > 17 and edad < 60:
  print("Puede pasar")
elif edad > 59:
  print("Puede pasar y tiene descuento ")
else:
  print(" No puede pasar")
# Out:
# yo tengo 2 hermanos.
# mi estatura es de 1.85 m.
# ¿La persona es mayor de edad? True
# La UTC Toreo se encuentra en Av. Ing. Militares y Av. Mexico Tacuba
# El resultado es: 0.140625
# Ingresa el dividendo: 12
# Ingresa el divisor:3
# 12 entre 3 da un cociente 4 y un residuo 0
# Puede pasar y tiene descuento
